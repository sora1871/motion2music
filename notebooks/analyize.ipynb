# %%
import pandas as pd

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\21td031\Documents\motion2music

# %%
# import os
# from scripts.extract_pose import extract_pose_from_video

# input_dir = "data/raw/"
# output_dir = "data/features/default"
# os.makedirs(output_dir, exist_ok=True)

# video_files = sorted([f for f in os.listdir(input_dir) if f.endswith(".mp4")])

# for filename in video_files:
#     video_path = os.path.join(input_dir, filename)
#     output_csv = os.path.join(output_dir, filename.replace(".mp4", ".csv"))
#     print(f"抽出中: {filename}")
#     extract_pose_from_video(video_path, output_csv)

# %%
import os
import pandas as pd
from scripts.preprocess import normalize_pose_df

input_dir = "data/features/default"
output_dir = "data/normalized_features/default"
os.makedirs(output_dir, exist_ok=True)

csv_files = sorted([f for f in os.listdir(input_dir) if f.endswith(".csv")])

for fname in csv_files:
    input_path = os.path.join(input_dir, fname)
    output_path = os.path.join(output_dir, fname.replace(".csv", "_normalized.csv"))

    df = pd.read_csv(input_path)
    normalized_df = normalize_pose_df(df)
    normalized_df.to_csv(output_path, index=False)

    print(f"✔ 正規化完了: {fname} → {output_path}")
# Out:
# ✔ 正規化完了: 久世.csv → data/normalized_features/default\久世_normalized.csv
# ✔ 正規化完了: 十河.csv → data/normalized_features/default\十河_normalized.csv
# ✔ 正規化完了: 十河1人目リラックスVID20250616115433.csv → data/normalized_features/default\十河1人目リラックスVID20250616115433_normalized.csv
# ✔ 正規化完了: 十河1人目嬉しいVID20250616115335.csv → data/normalized_features/default\十河1人目嬉しいVID20250616115335_normalized.csv
# ✔ 正規化完了: 十河1人目悲しいVID20250616115353.csv → data/normalized_features/default\十河1人目悲しいVID20250616115353_normalized.csv
# ✔ 正規化完了: 十河1人目緊張VID20250616115419.csv → data/normalized_features/default\十河1人目緊張VID20250616115419_normalized.csv
# ✔ 正規化完了: 十河2人目リラックスVID20250616120023.csv → data/normalized_features/default\十河2人目リラックスVID20250616120023_normalized.csv
# ✔ 正規化完了: 十河2人目嬉しいVID20250616115944.csv → data/normalized_features/default\十河2人目嬉しいVID20250616115944_normalized.csv
# ✔ 正規化完了: 十河2人目悲しいVID20250616115957.csv → data/normalized_features/default\十河2人目悲しいVID20250616115957_normalized.csv
# ✔ 正規化完了: 十河2人目緊張VID20250616120010.csv → data/normalized_features/default\十河2人目緊張VID20250616120010_normalized.csv
# ✔ 正規化完了: 十河3人目リラックスVID20250616120127.csv → data/normalized_features/default\十河3人目リラックスVID20250616120127_normalized.csv
# ✔ 正規化完了: 十河3人目嬉しいVID20250616120042.csv → data/normalized_features/default\十河3人目嬉しいVID20250616120042_normalized.csv
# ✔ 正規化完了: 十河3人目悲しいVID20250616120100.csv → data/normalized_features/default\十河3人目悲しいVID20250616120100_normalized.csv
# ✔ 正規化完了: 十河3人目緊張VID20250616120112.csv → data/normalized_features/default\十河3人目緊張VID20250616120112_normalized.csv
# ✔ 正規化完了: 十河4人目リラックスVID20250616120356.csv → data/normalized_features/default\十河4人目リラックスVID20250616120356_normalized.csv
# ✔ 正規化完了: 十河4人目嬉しいVID20250616120305.csv → data/normalized_features/default\十河4人目嬉しいVID20250616120305_normalized.csv
# ✔ 正規化完了: 十河4人目悲しいVID20250616120318.csv → data/normalized_features/default\十河4人目悲しいVID20250616120318_normalized.csv
# ✔ 正規化完了: 十河4人目緊張VID20250616120342.csv → data/normalized_features/default\十河4人目緊張VID20250616120342_normalized.csv
# ✔ 正規化完了: 水谷.csv → data/normalized_features/default\水谷_normalized.csv

# %%
import pandas as pd

df = pd.read_csv("data/normalized_features/default/久世_normalized.csv")
desc = df.describe()

print("各列の平均 (should be ≈ 0):")
print(desc.loc["mean"].round(3))

print("\n標準偏差 (全体で ≈ 1程度に収まると理想):")
print(desc.loc["std"].round(3))
# Out:
# 各列の平均 (should be ≈ 0):
# P0_x     0.056
# P0_y    -0.993
# P1_x     0.123
# P1_y    -1.046
# P2_x     0.161
#          ...
# P30_y    1.433
# P31_x    0.007
# P31_y    1.567
# P32_x   -0.147
# P32_y    1.573
# Name: mean, Length: 66, dtype: float64
#
# 標準偏差 (全体で ≈ 1程度に収まると理想):
# P0_x     0.077
# P0_y     0.051
# P1_x     0.064
# P1_y     0.057
# P2_x     0.059
#          ...
# P30_y    0.207
# P31_x    0.178
# P31_y    0.154
# P32_x    0.147
# P32_y    0.185
# Name: std, Length: 66, dtype: float64

# %%
import os
import pandas as pd
import numpy as np

input_dir = "data/normalized_features/default"
csv_files = sorted([f for f in os.listdir(input_dir) if f.endswith(".csv")])

all_data = []

for fname in csv_files:
    df = pd.read_csv(os.path.join(input_dir, fname))
    
    # 欠損値がある行はスキップ（安全対策）
    df = df.dropna()
    
    # データを numpy に追加（フレーム単位）
    all_data.append(df.values)  # shape = [T, 66]

# 結合 → [全フレーム数, 66]
pose_array = np.vstack(all_data)

print("最終データ形状:", pose_array.shape)  # 例：[10000, 66]
# Out:
# 最終データ形状: (2555, 66)

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import numpy as np

# データをTensor化
X = torch.tensor(pose_array, dtype=torch.float32)

# ミニバッチ学習用データローダー
batch_size = 64
dataset = TensorDataset(X)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %%
class MLP_AutoEncoder(nn.Module):
    def __init__(self, input_dim=66, latent_dim=16):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, latent_dim),
        )
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, 128),
            nn.ReLU(),
            nn.Linear(128, input_dim),
        )

    def forward(self, x):
        z = self.encoder(x)
        x_hat = self.decoder(z)
        return x_hat, z

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.2.2+cpu
# False

# %%
model = MLP_AutoEncoder()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
loss_fn = nn.MSELoss()

num_epochs = 50

for epoch in range(num_epochs):
    total_loss = 0
    for batch in dataloader:
        x = batch[0]  # shape = [B, 66]
        x_hat, _ = model(x)

        loss = loss_fn(x_hat, x)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    print(f"Epoch {epoch+1}/{num_epochs} - Loss: {total_loss:.4f}")
# Out:
# Epoch 1/50 - Loss: 22.7305
# Epoch 2/50 - Loss: 8.0127
# Epoch 3/50 - Loss: 5.1475
# Epoch 4/50 - Loss: 3.5818
# Epoch 5/50 - Loss: 2.5597
# Epoch 6/50 - Loss: 1.5884
# Epoch 7/50 - Loss: 2.3523
# Epoch 8/50 - Loss: 2.3160
# Epoch 9/50 - Loss: 2.5605
# Epoch 10/50 - Loss: 1.4610
# Epoch 11/50 - Loss: 1.3061
# Epoch 12/50 - Loss: 0.9729
# Epoch 13/50 - Loss: 0.9831
# Epoch 14/50 - Loss: 1.1265
# Epoch 15/50 - Loss: 1.2803
# Epoch 16/50 - Loss: 1.6895
# Epoch 17/50 - Loss: 3.0736
# Epoch 18/50 - Loss: 2.2650
# Epoch 19/50 - Loss: 0.6371
# Epoch 20/50 - Loss: 0.6216
# Epoch 21/50 - Loss: 0.6825
# Epoch 22/50 - Loss: 0.8597
# Epoch 23/50 - Loss: 0.7223
# Epoch 24/50 - Loss: 0.7112
# Epoch 25/50 - Loss: 0.8779
# Epoch 26/50 - Loss: 0.8325
# Epoch 27/50 - Loss: 0.6962
# Epoch 28/50 - Loss: 1.1598
# Epoch 29/50 - Loss: 0.9066
# Epoch 30/50 - Loss: 0.7866
# Epoch 31/50 - Loss: 0.5739
# Epoch 32/50 - Loss: 0.7203
# Epoch 33/50 - Loss: 0.7436
# Epoch 34/50 - Loss: 1.1385
# Epoch 35/50 - Loss: 0.9950
# Epoch 36/50 - Loss: 1.5093
# Epoch 37/50 - Loss: 0.9172
# Epoch 38/50 - Loss: 0.9762
# Epoch 39/50 - Loss: 1.1274
# Epoch 40/50 - Loss: 2.0994
# Epoch 41/50 - Loss: 2.4953
# Epoch 42/50 - Loss: 1.7645
# Epoch 43/50 - Loss: 0.7885
# Epoch 44/50 - Loss: 1.1947
# Epoch 45/50 - Loss: 1.1847
# Epoch 46/50 - Loss: 1.4616
# Epoch 47/50 - Loss: 0.6280
# Epoch 48/50 - Loss: 1.8466
# Epoch 49/50 - Loss: 1.8390
# Epoch 50/50 - Loss: 1.4462

# %%
with torch.no_grad():
    _, latent_vecs = model(X)  # shape = [2555, latent_dim]
latent_vecs_np = latent_vecs.numpy()

# %%
latent_vecs_np  # shape = [2555, 16]
# Out:
# array([[-3.0730057 ,  0.718906  ,  0.12752937, ..., -0.3590496 ,
#          0.45600268,  0.68475306],
#        [-3.6471355 ,  1.2096994 ,  0.30568507, ..., -0.6220149 ,
#          0.5985774 ,  0.9157628 ],
#        [-2.2837977 ,  0.33982348,  0.08013402, ..., -0.12156564,
#          0.47523522,  0.31654236],
#        ...,
#        [-2.6257832 ,  0.36289316,  0.24172051, ..., -0.1660443 ,
#          0.25957945,  0.551324  ],
#        [-2.6678648 ,  0.3643161 ,  0.26781005, ..., -0.17170662,
#          0.2357679 ,  0.5490395 ],
#        [-2.675814  ,  0.36232424,  0.27930897, ..., -0.17353246,
#          0.21537834,  0.5452496 ]], dtype=float32)

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

tsne = TSNE(n_components=2, random_state=42, perplexity=30)
latent_2d = tsne.fit_transform(latent_vecs_np)

plt.figure(figsize=(8, 6))
plt.scatter(latent_2d[:, 0], latent_2d[:, 1], s=5, alpha=0.7)
plt.title("Latent Space Visualization (t-SNE)")
plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.grid(True)
plt.show()

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5, random_state=42)
labels = kmeans.fit_predict(latent_vecs_np)

plt.figure(figsize=(8, 6))
plt.scatter(latent_2d[:, 0], latent_2d[:, 1], c=labels, cmap='tab10', s=5)
plt.title("Latent Space with KMeans Clusters")
plt.grid(True)
plt.show()

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=2)
latent_pca = pca.fit_transform(latent_vecs_np)

plt.figure(figsize=(8, 6))
plt.scatter(latent_pca[:, 0], latent_pca[:, 1], s=5, alpha=0.7)
plt.title("Latent Space Visualization (PCA)")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.grid(True)
plt.show()

# %%
print("Explained variance ratio:", pca.explained_variance_ratio_)
print("累積寄与率:", pca.explained_variance_ratio_.sum())
# Out:
# Explained variance ratio: [0.69138235 0.17834018]
# 累積寄与率: 0.86972255

# %%
import numpy as np

# pca.components_ → shape: [n_components, n_features]
# ここでは pca.components_[0] が PC1 の重みベクトル

feature_names = [f"P{i}_{axis}" for i in range(33) for axis in ['x', 'y']]

# 主成分1に強く寄与している特徴量 TOP10
pc1_weights = pca.components_[0]
pc1_top_idx = np.argsort(np.abs(pc1_weights))[::-1][:10]

print("主成分1に最も寄与している特徴量:")
for i in pc1_top_idx:
    print(f"{feature_names[i]}: {pc1_weights[i]:.4f}")
# Out:
# 主成分1に最も寄与している特徴量:
# P5_y: 0.5424
# P0_x: -0.4036
# P6_x: -0.3950
# P1_y: -0.2945
# P4_y: 0.2441
# P3_x: -0.2340
# P1_x: 0.2261
# P3_y: -0.2078
# P0_y: 0.1754
# P2_x: -0.1589

# %%
pc2_weights = pca.components_[1]
pc2_top_idx = np.argsort(np.abs(pc2_weights))[::-1][:10]

print("\n主成分2に最も寄与している特徴量:")
for i in pc2_top_idx:
    print(f"{feature_names[i]}: {pc2_weights[i]:.4f}")
# Out:
# 主成分2に最も寄与している特徴量:
# P4_y: 0.6390
# P0_x: 0.4154
# P3_x: -0.3330
# P3_y: 0.2652
# P2_y: 0.2493
# P1_y: 0.2094
# P6_y: 0.1810
# P5_y: 0.1801
# P1_x: 0.1521
# P4_x: 0.0947

# %%
# エンコーダの重みを取得
first_linear = model.encoder[0]  # 66 → 128
second_linear = model.encoder[2] # 128 → 16

# 重み行列の取得（[出力, 入力] 形式）
W1 = first_linear.weight.detach().numpy()   # shape: (128, 66)
W2 = second_linear.weight.detach().numpy()  # shape: (16, 128)

# 確認
print("W1 shape:", W1.shape)
print("W2 shape:", W2.shape)
# Out:
# W1 shape: (128, 66)
# W2 shape: (16, 128)

# %%
W_combined = np.dot(W2, W1)  # shape: (16, 66)
W_combined.shape
# Out:
# (16, 66)

# %%
# 入力特徴量の名前（例：P0_x, P0_y, ..., P32_y）
feature_names = [f"P{i}_{axis}" for i in range(33) for axis in ['x', 'y']]

# 潜在次元の名前（例：z0, z1, ..., z15）
latent_names = [f"z{i}" for i in range(W_combined.shape[0])]

# 確認
print("特徴量数:", len(feature_names))
print("潜在次元数:", len(latent_names))
# Out:
# 特徴量数: 66
# 潜在次元数: 16

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# 重みの絶対値をとることで「影響の強さ」を可視化
weight_matrix = np.abs(W_combined)

plt.figure(figsize=(18, 6))
sns.heatmap(weight_matrix, 
            xticklabels=feature_names, 
            yticklabels=latent_names, 
            cmap="YlGnBu", 
            cbar=True)

plt.title("Latent Dimension vs Input Feature Importance (AE Encoder Weights)")
plt.xlabel("Input Feature (Pose: P0_x ~ P32_y)")
plt.ylabel("Latent Dimension (z0 ~ z15)")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
